# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

# %%
df = pd.read_csv('output data/spreadspoke_scores_trimmed.csv')
df.head()
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0    09/03/2000             2000             1             False
# 1    09/03/2000             2000             1             False
# 2    09/03/2000             2000             1             False
# 3    09/03/2000             2000             1             False
# 4    09/03/2000             2000             1             False
#
#            team_home  score_home  score_away             team_away  \
# 0    Atlanta Falcons          36          28   San Francisco 49ers
# 1      Buffalo Bills          16          13      Tennessee Titans
# 2   Cleveland Browns           7          27  Jacksonville Jaguars
# 3     Dallas Cowboys          14          41   Philadelphia Eagles
# 4  Green Bay Packers          16          20         New York Jets
#
#        team_favorite_id  spread_favorite  over_under_line  \
# 0       Atlanta Falcons             -6.5             46.5
# 1         Buffalo Bills             -1.0             40.0
# 2  Jacksonville Jaguars            -10.5             38.5
# 3        Dallas Cowboys             -6.0             39.5
# 4     Green Bay Packers             -2.5             44.0
#
#                 stadium  stadium_neutral              team_win home_away_win  \
# 0          Georgia Dome            False       Atlanta Falcons          Home
# 1  Ralph Wilson Stadium            False         Buffalo Bills          Home
# 2   FirstEnergy Stadium            False  Jacksonville Jaguars          Away
# 3         Texas Stadium            False   Philadelphia Eagles          Away
# 4         Lambeau Field            False         New York Jets          Away
#
#    fav_win over_under_result
# 0     True              Over
# 1     True             Under
# 2     True             Under
# 3    False              Over
# 4    False             Under

# %%
df.describe()
# Out:
#        schedule_season   score_home   score_away  spread_favorite  \
# count      5324.000000  5324.000000  5324.000000      5324.000000
# mean       2009.527047    23.159842    20.710368        -5.397164
# std           5.754236    10.382276    10.088146         3.423281
# min        2000.000000     0.000000     0.000000       -26.500000
# 25%        2005.000000    16.000000    13.000000        -7.000000
# 50%        2010.000000    23.000000    20.000000        -4.500000
# 75%        2015.000000    30.000000    27.000000        -3.000000
# max        2019.000000    62.000000    59.000000         0.000000
#
#        over_under_line
# count      5324.000000
# mean         43.259673
# std           4.946316
# min          30.000000
# 25%          40.000000
# 50%          43.500000
# 75%          46.500000
# max          63.500000

# %%
dfvis1 = df[['schedule_season','score_home','score_away']]
dfvis1.head()
# Out:
#    schedule_season  score_home  score_away
# 0             2000          36          28
# 1             2000          16          13
# 2             2000           7          27
# 3             2000          14          41
# 4             2000          16          20

# %%
dfvis1.groupby('schedule_season').mean()
# Out:
#                  score_home  score_away
# schedule_season
# 2000              22.169884   18.922780
# 2001              21.343629   19.196911
# 2002              23.018727   20.640449
# 2003              22.689139   19.101124
# 2004              22.895131   20.250936
# 2005              22.378277   18.722846
# 2006              21.303371   20.209738
# 2007              23.157303   20.228464
# 2008              23.183521   20.842697
# 2009              22.779026   20.382022
# 2010              23.000000   21.318352
# 2011              23.981273   20.509363
# 2012              24.108614   21.666667
# 2013              24.891386   21.977528
# 2014              23.973783   21.295880
# 2015              23.531835   21.932584
# 2016              24.385768   21.352060
# 2017              23.104869   20.520599
# 2018              24.344569   22.205993
# 2019              22.872659   22.831461

# %%
dfvis1line = dfvis1.groupby('schedule_season').mean()
dfvis1line.head()
# Out:
#                  score_home  score_away
# schedule_season
# 2000              22.169884   18.922780
# 2001              21.343629   19.196911
# 2002              23.018727   20.640449
# 2003              22.689139   19.101124
# 2004              22.895131   20.250936

# %%
dfvis1line.plot()
plt.title('Average NFL Score Home vs Away')
plt.xlabel('Season')
plt.ylabel('Average Points Scored')
plt.xticks(np.arange(2000, 2020, 2.0))
plt.savefig('Viz_img/Home_vs_Away_Points.png')

# %%
dfvis2 = df[['schedule_date','stadium']]
dfvis2
# Out:
#      schedule_date               stadium
# 0       09/03/2000          Georgia Dome
# 1       09/03/2000  Ralph Wilson Stadium
# 2       09/03/2000   FirstEnergy Stadium
# 3       09/03/2000         Texas Stadium
# 4       09/03/2000         Lambeau Field
# ...            ...                   ...
# 5319    01/12/2020         Lambeau Field
# 5320    01/12/2020     Arrowhead Stadium
# 5321    01/19/2020     Arrowhead Stadium
# 5322    01/19/2020        Levi's Stadium
# 5323    02/02/2020     Hard Rock Stadium
#
# [5324 rows x 2 columns]

# %%
dfvis2.groupby('stadium').count()
# Out:
#                                schedule_date
# stadium
# AT&T Stadium                              25
# Alamo Dome                                 3
# Alltel Stadium                             1
# Arrowhead Stadium                        167
# Bank of America Stadium                  166
# ...                                      ...
# Twickenham Stadium                         3
# U.S. Bank Stadium                         34
# University of Phoenix Stadium            165
# Veterans Stadium                          28
# Wembley Stadium                           22
#
# [66 rows x 1 columns]

# %%
dfvis2bar = dfvis2.groupby('stadium').count()
dfvis2bar.plot(kind='bar', figsize=(30,10), legend=None, title="Games Played at Each Stadium").set_ylabel('Games Played')
plt.savefig('Viz_img/Games_Per_Stadium.png')

# %%
dfvis3 = df.groupby('team_home').mean()
dfvis3 = dfvis3['over_under_line']
dfvis3bar = dfvis3.plot(kind='bar', figsize=(20,10), ylim=(35,50), title='Average Over/Under Line by Team').set_ylabel('Over/Under Line')
plt.savefig('Viz_img/Avg_OU_byTeam.png')

# %%
#Creates dictionaries for wins as favorites and wins as underdogs. Keys will be team names and values will be win counts
fav_wins = {}
underdog_wins = {}

# %%
#Loops through the dataframe
for index, row in df.iterrows():
    
    #Finds all rows where the favorite won
    if df.loc[index, 'fav_win']:
        
        #If the team is not in the dictionary yet adds it with a win count of one. Otherwise, adds one to the win count
        if df.loc[index, 'team_win'] not in fav_wins:
            fav_wins[df.loc[index, 'team_win']] = 1
        else:
            fav_wins[df.loc[index, 'team_win']] += 1

# %%
#Loops through the dataframe
for index, row in df.iterrows():
    
    #Finds all rows where the underdog won
    if not(df.loc[index, 'fav_win']):
        
        #If the team is not in the dictionary yet adds it with a win count of one. Otherwise, adds one to the win count
        if df.loc[index, 'team_win'] not in underdog_wins:
            underdog_wins[df.loc[index, 'team_win']] = 1
        else:
            underdog_wins[df.loc[index, 'team_win']] += 1

# %%
#Creates a dataframe with the team names as indices and favorite/underdog wins as columns
favdf = pd.DataFrame.from_dict(fav_wins,orient = 'index')
underdogdf = pd.DataFrame.from_dict(underdog_wins,orient='index')
dfvis4 = favdf.merge(underdogdf,right_index=True,left_index=True,how="outer")
dfvis4.columns = ['Favorite Wins','Underdog Wins']

#Creates a bar graph of them and reformat
dfvis4.plot(kind="bar",figsize=(20,10))

plt.title("Favorite/Underdog Wins by Team")
plt.xlabel("Teams")
plt.ylabel("Wins")

plt.savefig('Viz_img/Favorite-Underdog_Wins_byTeam.png')
